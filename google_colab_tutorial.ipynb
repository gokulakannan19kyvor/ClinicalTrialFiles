# %% [markdown]
# <a href="https://colab.research.google.com/github/sgokulakannankg19/ClinicalTrialFiles/blob/main/google_colab_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade gspread
# Out:
# ...
#   Attempting uninstall: gspread
#     Found existing installation: gspread 3.4.2
#     Uninstalling gspread-3.4.2:
#       Successfully uninstalled gspread-3.4.2
# ...

# %%
from google.colab import auth
auth.authenticate_user()

import pandas as pd
import requests

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %%
df = pd.read_excel("/content/sample_data/MASTER_GeneAliases.xlsx", sheet_name="COMPILATION")
df
# Out:
#       Unnamed: 0  ...                                        Unnamed: 10
# 0           Gene  ...                                               HGNC
# 1           ABL1  ...  ABL proto-oncogene 1,non-receptor tyrosine kin...
# 2           AKT1  ...  AKT serine/threonine kinase 1,RAC,PKB,PRKBA,AK...
# 3           AKT2  ...                 AKT serine/threonine kinase 2,PKBβ
# 4           AKT3  ...  AKT serine/threonine kinase 3,PKBG,RAC-gamma,P...
# ...          ...  ...                                                ...
# 69751     ZRF1PS  ...                                                NaN
# 69752        ZRK  ...       zona pellucida receptor tyrosine kinase,95kD
# 69753        ZRS  ...                                                NaN
# 69754    ZWINTAS  ...       ZWINT antisense RNA,MPP5,MPHOSPH5,NCRNA00018
# 69755       ZWS1  ...  symbol withdrawn,see [HGNC:8850](/data/gene-sy...
#
# [69756 rows x 11 columns]

# %%
df.shape
# Out:
# (69756, 11)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'SOURCE(S)', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'SYNONYMS', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
df['Unnamed: 0']
# Out:
# 0           Gene
# 1           ABL1
# 2           AKT1
# 3           AKT2
# 4           AKT3
#           ...
# 69751     ZRF1PS
# 69752        ZRK
# 69753        ZRS
# 69754    ZWINTAS
# 69755       ZWS1
# Name: Unnamed: 0, Length: 69756, dtype: object

# %%
gene_list = df['Unnamed: 0'][1:].to_list()

# %%
gene_list
# Out:
# ['ABL1',
#  'AKT1',
#  'AKT2',
#  'AKT3',
#  'ALK',
#  'AR',
#  'ARAF',
#  'ARID1A',
#  'ATM',
#  'ATR',
#  'ATRX',
#  'AXL',
#  'BAD',
#  'BAP1',
#  'BRAF',
#  'BRCA1',
#  'BRCA2',
#  'BTK',
#  'CBL',
#  'CCND1',
#  'CCND2',
#  'CCND3',
#  'CCNE1',
#  'CDK12',
#  'CDK2',
#  'CDK4',
#  'CDK6',
#  'CDKN1B',
#  'CTNNB1',
#  'DDR2',
#  'EGFR',
#  'ERBB2',
#  'ERBB3',
#  'ERBB4',
#  'ERG',
#  'ESR1',
#  'ETV1',
#  'ETV4',
#  'ETV5',
#  'FGFR1',
#  'FGFR2',
#  'FGFR3',
#  'FGFR4',
#  'GNA11',
#  'GNAQ',
#  'HRAS',
#  'IDH1',
#  'IDH2',
#  'JAK1',
#  'JAK2',
#  'JAK3',
#  'KIT',
#  'KRAS',
#  'MAP2K1',
#  'MAP2K2',
#  'MDM2',
#  'MET',
#  'MTOR',
#  'MYC',
#  'MYCN',
#  'NRAS',
#  'NTRK1',
#  'NTRK2',
#  'NTRK3',
#  'PDGFRA',
#  'PDK1',
#  'PIK3C3',
#  'PIK3CA',
#  'PIK3CB',
#  'PIK3CD',
#  'PIK3CG',
#  'PIK3R1',
#  'PIK3R2',
#  'PIK3R3',
#  'PIK3R5',
#  'PPARG',
#  'PTEN',
#  'RAF1',
#  'RET',
#  'RHEB',
#  'RICTOR',
#  'ROS1',
#  'RPS6KA1',
#  'RPS6KA4',
#  'RPS6KB1',
#  'RPS6KB2',
# ...

# %%
len(gene_list)
# Out:
# 69755

# %%
gene_list = list(set(gene_list))
len(gene_list)
# Out:
# 69755

# %%
if "BRAF" in gene_list:
  print("found")
# Out:
# found
